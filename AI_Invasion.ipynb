# %%
import pandas as pd
data = [['ola', 20], ['ayo', 25], ['femi', 10]]
df = pd.DataFrame (data, columns = ['Name', 'Age'])
df
# Out:
#    Name  Age
# 0   ola   20
# 1   ayo   25
# 2  femi   10

# %%
import pandas as pd
data = {'Name': ['olami','olaade','basit', 'ayigoro','sherif', ] ,'Matric No':['NSS/2019/001', 'NSS/2019/002', 'NSS/2019/004','CSE/2019/001','CSE/2019/002'], 'Department':['Networking and System Security', 'Networking and System Security', 'Networking and System Security','Software Engineering', 'Software Engineering']}
df = pd.DataFrame (data)
df
# Out:
#       Name     Matric No                      Department
# 0    olami  NSS/2019/001  Networking and System Security
# 1   olaade  NSS/2019/002  Networking and System Security
# 2    basit  NSS/2019/004  Networking and System Security
# 3  ayigoro  CSE/2019/001            Software Engineering
# 4   sherif  CSE/2019/002            Software Engineering

# %%
import numpy as np
matr = np.array([[1, 2], [3, 4]])
print(matr)
print('The shape of Z is' , matr.shape)
# Out:
# [[1 2]
#  [3 4]]
# The shape of Z is (2, 2)

# %%
import pandas as pd
Excel_df = pd.read_csv ('desktop/AIInvasion.csv' )
Excel_df
# Out:
#     S/N             STATE  AREA(km2)  POPULATION
# 0     0        Abia State       6320     2845380
# 1     1     Adamawa State      36917     3178950
# 2     2  Akwa Ibom State        7081     3178950
# 3     3     Anambra State       4844     4177828
# 4     4      Bauchi State      45837     4653066
# 5     5     Bayelsa State      10773     1704515
# 6     6       Benue State      34059     4253641
# 7     7       Borno State      70898     4171104
# 8     8       Cross River      20156     2892988
# 9     9       Delta State      17698     4112445
# 10   10      Ebonyi State       5670     2176947
# 11   11         Edo State      17802     3233366
# 12   12       Ekiti State       6353     2398957
# 13   13       Enugu State       7161     3267837
# 14   14               FCT       7315     1405201
# 15   15       Gombe State      18768     2365040
# 16   16         Imo State       5530     3927563
# 17   17      Jigawa State      23154     4361002
# ...

# %%
import numpy as np
y = np.array([[3,4],[5,6]])
z = np.array([[1,2],[7,8]])
t = y + z
r = np.add(y,z)
t
r
# Out:
# array([[ 4,  6],
#        [12, 14]])

# %%
import pandas as pd
Excel_df = pd.read_csv ('desktop/AIInvasion.csv' )
Excel_df
# Out:
#     S/N             STATE  AREA(km2)  POPULATION
# 0     0        Abia State       6320     2845380
# 1     1     Adamawa State      36917     3178950
# 2     2  Akwa Ibom State        7081     3178950
# 3     3     Anambra State       4844     4177828
# 4     4      Bauchi State      45837     4653066
# 5     5     Bayelsa State      10773     1704515
# 6     6       Benue State      34059     4253641
# 7     7       Borno State      70898     4171104
# 8     8       Cross River      20156     2892988
# 9     9       Delta State      17698     4112445
# 10   10      Ebonyi State       5670     2176947
# 11   11         Edo State      17802     3233366
# 12   12       Ekiti State       6353     2398957
# 13   13       Enugu State       7161     3267837
# 14   14               FCT       7315     1405201
# 15   15       Gombe State      18768     2365040
# 16   16         Imo State       5530     3927563
# 17   17      Jigawa State      23154     4361002
# ...

# %%
Excel_df.describe()
# Out:
#              S/N     AREA(km2)    POPULATION
# count  37.000000     37.000000  3.700000e+01
# mean   18.000000  24990.864865  3.775879e+06
# std    10.824355  18243.870444  1.726418e+06
# min     0.000000   3345.000000  1.405201e+06
# 25%     9.000000   9251.000000  2.845380e+06
# 50%    18.000000  20156.000000  3.314043e+06
# 75%    27.000000  36800.000000  4.177828e+06
# max    36.000000  76363.000000  9.401288e+06

# %%
Excel_df['POPULATION'].mean()
# Out:
# 3775879.4594594594

# %%
Excel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S/N         37 non-null     int64
#  1   STATE       37 non-null     object
#  2   AREA(km2)   37 non-null     int64
#  3   POPULATION  37 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.3+ KB

# %%
Excel_df.columns
# Out:
# Index(['S/N', 'STATE', 'AREA(km2)', 'POPULATION'], dtype='object')

# %%
print (Excel_df[['STATE', 'POPULATION']])
print (Excel_df[['STATE']])
print (Excel_df['STATE'])
# Out:
#                STATE  POPULATION
# 0         Abia State     2845380
# 1      Adamawa State     3178950
# 2   Akwa Ibom State      3178950
# 3      Anambra State     4177828
# 4       Bauchi State     4653066
# 5      Bayelsa State     1704515
# 6        Benue State     4253641
# 7        Borno State     4171104
# 8        Cross River     2892988
# 9        Delta State     4112445
# 10      Ebonyi State     2176947
# 11         Edo State     3233366
# 12       Ekiti State     2398957
# 13       Enugu State     3267837
# 14               FCT     1405201
# 15       Gombe State     2365040
# 16         Imo State     3927563
# 17      Jigawa State     4361002
# 18      Kaduna State     6113503
# 19        Kano State     9401288
# 20     Katsina State     5801584
# 21       Kebbi State     3256541
# 22        Kogi State     3314043
# 23       Kwara State     2365353
# 24       Lagos State     9113605
# 25    Nasarawa State     1869377
# 26       Niger State     3954772
# ...

# %%
df = Excel_df.drop(['POPULATION'], axis = 1)
df
# Out:
#     S/N             STATE  AREA(km2)
# 0     0        Abia State       6320
# 1     1     Adamawa State      36917
# 2     2  Akwa Ibom State        7081
# 3     3     Anambra State       4844
# 4     4      Bauchi State      45837
# 5     5     Bayelsa State      10773
# 6     6       Benue State      34059
# 7     7       Borno State      70898
# 8     8       Cross River      20156
# 9     9       Delta State      17698
# 10   10      Ebonyi State       5670
# 11   11         Edo State      17802
# 12   12       Ekiti State       6353
# 13   13       Enugu State       7161
# 14   14               FCT       7315
# 15   15       Gombe State      18768
# 16   16         Imo State       5530
# 17   17      Jigawa State      23154
# 18   18      Kaduna State      46053
# 19   19        Kano State      20131
# 20   20     Katsina State      24192
# 21   21       Kebbi State      36800
# 22   22        Kogi State      29833
# 23   23       Kwara State      36825
# ...

# %%
df['POPULATION' ] = Excel_df ['POPULATION' ]
df
# Out:
#     S/N             STATE  AREA(km2)  POPULATION
# 0     0        Abia State       6320     2845380
# 1     1     Adamawa State      36917     3178950
# 2     2  Akwa Ibom State        7081     3178950
# 3     3     Anambra State       4844     4177828
# 4     4      Bauchi State      45837     4653066
# 5     5     Bayelsa State      10773     1704515
# 6     6       Benue State      34059     4253641
# 7     7       Borno State      70898     4171104
# 8     8       Cross River      20156     2892988
# 9     9       Delta State      17698     4112445
# 10   10      Ebonyi State       5670     2176947
# 11   11         Edo State      17802     3233366
# 12   12       Ekiti State       6353     2398957
# 13   13       Enugu State       7161     3267837
# 14   14               FCT       7315     1405201
# 15   15       Gombe State      18768     2365040
# 16   16         Imo State       5530     3927563
# 17   17      Jigawa State      23154     4361002
# ...

# %%
df['POPULATION'] = df['POPULATION'].astype('float')
df
# Out:
#     S/N             STATE  AREA(km2)  POPULATION
# 0     0        Abia State       6320   2845380.0
# 1     1     Adamawa State      36917   3178950.0
# 2     2  Akwa Ibom State        7081   3178950.0
# 3     3     Anambra State       4844   4177828.0
# 4     4      Bauchi State      45837   4653066.0
# 5     5     Bayelsa State      10773   1704515.0
# 6     6       Benue State      34059   4253641.0
# 7     7       Borno State      70898   4171104.0
# 8     8       Cross River      20156   2892988.0
# 9     9       Delta State      17698   4112445.0
# 10   10      Ebonyi State       5670   2176947.0
# 11   11         Edo State      17802   3233366.0
# 12   12       Ekiti State       6353   2398957.0
# 13   13       Enugu State       7161   3267837.0
# 14   14               FCT       7315   1405201.0
# 15   15       Gombe State      18768   2365040.0
# 16   16         Imo State       5530   3927563.0
# 17   17      Jigawa State      23154   4361002.0
# ...

# %%
pd.to_numeric(df['POPULATION'], downcast = 'integer')
# Out:
# 0     2845380
# 1     3178950
# 2     3178950
# 3     4177828
# 4     4653066
# 5     1704515
# 6     4253641
# 7     4171104
# 8     2892988
# 9     4112445
# 10    2176947
# 11    3233366
# 12    2398957
# 13    3267837
# 14    1405201
# 15    2365040
# 16    3927563
# 17    4361002
# 18    6113503
# 19    9401288
# 20    5801584
# 21    3256541
# 22    3314043
# 23    2365353
# 24    9113605
# 25    1869377
# 26    3954772
# 27    3751140
# 28    3460877
# 29    3416959
# 30    5580894
# 31    3206531
# 32    5198605
# 33    3702676
# 34    2294800
# 35    2321339
# 36    3278873
# Name: POPULATION, dtype: int32

# %%
df['AreaPopu'] = df['AREA(km2)'] + df['POPULATION']
df.columns
# Out:
# Index(['S/N', 'STATE', 'AREA(km2)', 'POPULATION', 'AreaPopu'], dtype='object')

# %%
df.sort_index (inplace = True, ascending = False)
df
# Out:
#     S/N             STATE  AREA(km2)  POPULATION   AreaPopu
# 36   36     Zamfara State      39762   3278873.0  3318635.0
# 35   35        Yobe State      45502   2321339.0  2366841.0
# 34   34      Taraba State      54473   2294800.0  2349273.0
# 33   33      Sokoto State      25973   3702676.0  3728649.0
# 32   32      Rivers State      11077   5198605.0  5209682.0
# 31   31     Plateau State      30913   3206531.0  3237444.0
# 30   30         Oyo State      28454   5580894.0  5609348.0
# 29   29        Osun State       9251   3416959.0  3426210.0
# 28   28        Ondo State      15500   3460877.0  3476377.0
# 27   27        Ogun State      16762   3751140.0  3767902.0
# 26   26       Niger State      76363   3954772.0  4031135.0
# 25   25    Nasarawa State      27117   1869377.0  1896494.0
# 24   24       Lagos State       3345   9113605.0  9116950.0
# 23   23       Kwara State      36825   2365353.0  2402178.0
# 22   22        Kogi State      29833   3314043.0  3343876.0
# ...
